# %%
import os
print(os.listdir("/kaggle/input"))
# Out:
# ['datasets']

# %%
data_dir = "/kaggle/input/datasets/tannurawat32/split-data/split_data"

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader

# %%
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# %%
train_dataset = datasets.ImageFolder(f"{data_dir}/train", transform=train_transform)
val_dataset = datasets.ImageFolder(f"{data_dir}/val", transform=val_transform)

# %%
train_loader = DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True,
    num_workers=4,
    pin_memory=True
)

val_loader = DataLoader(
    val_dataset,
    batch_size=32,
    shuffle=False,
    num_workers=4,
    pin_memory=True
)

# %%
model = models.mobilenet_v2(weights="IMAGENET1K_V1")

num_classes = len(train_dataset.classes)
model.classifier[1] = nn.Linear(model.last_channel, num_classes)
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 64.5MB/s]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

print(device)
# Out:
# cuda

# %%
for param in model.features.parameters():
    param.requires_grad = False

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
best_val_acc = 0  

def evaluate(model, loader):
    model.eval()
    correct, total = 0, 0

    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)

            correct += (preds == labels).sum().item()
            total += labels.size(0)

    return correct / total
    
def train_model(model, train_loader, val_loader, epochs=5,
                train_acc_list=None, val_acc_list=None, loss_list=None):

    global best_val_acc

    # Initialize lists
    if train_acc_list is None:
        train_acc_list = []
    if val_acc_list is None:
        val_acc_list = []
    if loss_list is None:
        loss_list = []

    print("Training started")

    for epoch in range(epochs):
        model.train()
        running_loss = 0
        correct, total = 0, 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # Track loss
            running_loss += loss.item() * images.size(0)

            # Predictions
            _, preds = torch.max(outputs, 1)
            correct += (preds == labels).sum().item()
            total += labels.size(0)

        # Calculate metrics
        train_acc = correct / total
        epoch_loss = running_loss / total
        val_acc = evaluate(model, val_loader)

        # Store results
        train_acc_list.append(train_acc)
        val_acc_list.append(val_acc)
        loss_list.append(epoch_loss)

        # Print progress
        print(f"Epoch {len(train_acc_list)}")
        print(f"Loss: {epoch_loss:.4f} | Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f}")
        print("-" * 40)

        # Save best model
        if val_acc > best_val_acc:
            best_val_acc = val_acc
            torch.save(model.state_dict(), "/kaggle/working/best_model.pth")

    return train_acc_list, val_acc_list, loss_list

# %%
train_acc, val_acc, loss = train_model(model, train_loader, val_loader, epochs=5)
# Out:
# Training started
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1
# Loss: 2.4862 | Train Acc: 0.4425 | Val Acc: 0.5825
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 2
# Loss: 1.5387 | Train Acc: 0.6107 | Val Acc: 0.6578
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 3
# Loss: 1.2717 | Train Acc: 0.6623 | Val Acc: 0.6728
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 4
# Loss: 1.1318 | Train Acc: 0.6954 | Val Acc: 0.6734
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 5
# Loss: 1.0475 | Train Acc: 0.7071 | Val Acc: 0.6722
# ----------------------------------------

# %%
for param in model.features.parameters():
    param.requires_grad = True

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# %%
train_acc, val_acc, loss = train_model(
    model, train_loader, val_loader,
    epochs=5,
    train_acc_list=train_acc,
    val_acc_list=val_acc,
    loss_list=loss
)
# Out:
# Training started
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 6
# Loss: 0.8065 | Train Acc: 0.7705 | Val Acc: 0.7688
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 7
# Loss: 0.5244 | Train Acc: 0.8492 | Val Acc: 0.7924
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 8
# Loss: 0.3777 | Train Acc: 0.8923 | Val Acc: 0.8097
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 9
# Loss: 0.2931 | Train Acc: 0.9150 | Val Acc: 0.8120
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 10
# Loss: 0.2124 | Train Acc: 0.9435 | Val Acc: 0.8200
# ----------------------------------------

# %%
model.classifier = nn.Sequential(
    nn.Dropout(0.3),
    nn.Linear(model.last_channel, num_classes)
)

model = model.to(device)  

for param in model.parameters():
    param.requires_grad = True

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer, step_size=2, gamma=0.1
)

# %%
new_train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])
train_dataset = datasets.ImageFolder(f"{data_dir}/train", transform=new_train_transform)

# %%
train_loader = DataLoader(
    train_dataset,
    batch_size=32,
    shuffle=True,
    num_workers=4,
    pin_memory=True
)

# %%
train_acc, val_acc, loss = train_model(
    model, train_loader, val_loader,
    epochs=3,
    train_acc_list=train_acc,
    val_acc_list=val_acc,
    loss_list=loss
)
# Out:
# Training started
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 11
# Loss: 2.0257 | Train Acc: 0.5668 | Val Acc: 0.7223
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 12
# Loss: 1.0080 | Train Acc: 0.7543 | Val Acc: 0.7786
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 13
# Loss: 0.6718 | Train Acc: 0.8287 | Val Acc: 0.8079
# ----------------------------------------

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5)

# %%
train_acc, val_acc, loss = train_model(
    model, train_loader, val_loader,
    epochs=5,
    train_acc_list=train_acc,
    val_acc_list=val_acc,
    loss_list=loss
)
# Out:
# Training started
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 14
# Loss: 0.4655 | Train Acc: 0.8932 | Val Acc: 0.8171
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 15
# Loss: 0.4169 | Train Acc: 0.9041 | Val Acc: 0.8183
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 16
# Loss: 0.3893 | Train Acc: 0.9150 | Val Acc: 0.8275
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 17
# Loss: 0.3663 | Train Acc: 0.9198 | Val Acc: 0.8292
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 18
# Loss: 0.3438 | Train Acc: 0.9244 | Val Acc: 0.8269
# ----------------------------------------

# %%
train_acc, val_acc, loss = train_model(
    model, train_loader, val_loader,
    epochs=2,
    train_acc_list=train_acc,
    val_acc_list=val_acc,
    loss_list=loss
)
# Out:
# Training started
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 19
# Loss: 0.3404 | Train Acc: 0.9241 | Val Acc: 0.8275
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 20
# Loss: 0.3142 | Train Acc: 0.9337 | Val Acc: 0.8327
# ----------------------------------------

# %%
train_acc, val_acc, loss = train_model(
    model, train_loader, val_loader,
    epochs=4,
    train_acc_list=train_acc,
    val_acc_list=val_acc,
    loss_list=loss
)
# Out:
# Training started
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 21
# Loss: 0.3038 | Train Acc: 0.9322 | Val Acc: 0.8281
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 22
# Loss: 0.2871 | Train Acc: 0.9397 | Val Acc: 0.8327
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 23
# Loss: 0.2752 | Train Acc: 0.9435 | Val Acc: 0.8309
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 24
# Loss: 0.2540 | Train Acc: 0.9515 | Val Acc: 0.8350
# ----------------------------------------

# %%
train_acc, val_acc, loss = train_model(
    model, train_loader, val_loader,
    epochs=2,
    train_acc_list=train_acc,
    val_acc_list=val_acc,
    loss_list=loss
)
# Out:
# Training started
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 25
# Loss: 0.2502 | Train Acc: 0.9509 | Val Acc: 0.8315
# ----------------------------------------
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 26
# Loss: 0.2351 | Train Acc: 0.9546 | Val Acc: 0.8350
# ----------------------------------------

# %%
test_dataset = datasets.ImageFolder(f"{data_dir}/test", transform=val_transform)

test_loader = DataLoader(
    test_dataset,
    batch_size=32,
    shuffle=False,
    num_workers=4,
    pin_memory=True
)

# %%
test_acc = evaluate(model, test_loader)
print("Test Accuracy:", test_acc)
# Out:
# Test Accuracy: 0.8237885462555066

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(train_acc) + 1)

# Accuracy
plt.figure()
plt.plot(epochs, train_acc)
plt.plot(epochs, val_acc)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Training vs Validation Accuracy")
plt.legend(["Train Accuracy", "Validation Accuracy"])
plt.show()


# Loss 
plt.figure()
plt.plot(epochs, loss)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.show()

# %%
best_epoch = val_acc.index(max(val_acc)) + 1
best_val = max(val_acc)

plt.figure()
plt.plot(epochs, val_acc)
plt.scatter(best_epoch, best_val)

plt.xlabel("Epochs")
plt.ylabel("Validation Accuracy")
plt.title("Validation Accuracy with Best Point")
plt.legend(["Val Accuracy", "Best"])
plt.show()

# %%
plt.figure()

plt.plot(epochs, train_acc)
plt.plot(epochs, val_acc)
plt.plot(epochs, loss)

plt.xlabel("Epochs")
plt.title("Training Overview")

plt.legend(["Train Accuracy", "Validation Accuracy", "Loss"])
plt.show()

# %%
import torch

def get_predictions(model, loader):
    model.eval()
    
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for images, labels in loader:
            images = images.to(device)
            outputs = model(images)

            _, preds = torch.max(outputs, 1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.numpy())

    return all_labels, all_preds

# %%
from sklearn.metrics import classification_report, accuracy_score

y_true, y_pred = get_predictions(model, test_loader)

# Accuracy
test_acc = accuracy_score(y_true, y_pred)
print("Test Accuracy:", test_acc)

# Full report
print(classification_report(y_true, y_pred, target_names=test_dataset.classes))
# Out:
# Test Accuracy: 0.8237885462555066
#                               precision    recall  f1-score   support
#
#                    adhirasam       1.00      0.62      0.77         8
#                    aloo_gobi       0.94      0.89      0.92        38
#                   aloo_matar       0.62      0.62      0.62         8
#                   aloo_methi       0.71      0.62      0.67         8
#            aloo_shimla_mirch       0.80      0.50      0.62         8
#                   aloo_tikki       0.29      0.25      0.27         8
#                       anarsa       0.75      0.38      0.50         8
#                      ariselu       0.42      0.62      0.50         8
#                 bandar_laddu       0.71      0.62      0.67         8
#                      basundi       0.38      0.38      0.38         8
#                      bhatura       1.00      0.50      0.67         8
#                bhindi_masala       0.97      0.99      0.98        68
#                      biryani       0.94      1.00      0.97        68
#               bisi_bele_bath       0.73      0.73      0.73        11
#                       boondi       1.00      0.75      0.86         8
#               butter_chicken       0.57      0.50      0.53         8
#                        chaat       0.73      0.67      0.70        12
#               chak_hao_kheer       0.83      0.62      0.71         8
#                    cham_cham       1.00      0.25      0.40         8
#                 chana_masala       0.67      0.75      0.71         8
#                      chapati       0.82      0.80      0.81       100
#                chhena_kheeri       0.17      0.12      0.14         8
#               chicken_razala       0.83      0.62      0.71         8
#                chicken_tikka       0.00      0.00      0.00         8
#         chicken_tikka_masala       0.29      0.25      0.27         8
#                       chikki       1.00      1.00      1.00         8
#            daal_baati_churma       0.50      0.38      0.43         8
#                    daal_puri       0.43      0.38      0.40         8
#                  dal_makhani       0.84      0.97      0.90       116
#                    dal_tadka       0.50      0.25      0.33         8
#                dharwad_pedha       0.86      0.75      0.80         8
#                     doodhpak       0.50      0.25      0.33         8
#                         dosa       0.83      0.36      0.50        14
#             double_ka_meetha       0.44      0.50      0.47         8
#                     dum_aloo       0.73      0.92      0.81        38
#               gajar_ka_halwa       0.67      0.75      0.71         8
#                      gavvalu       0.83      0.62      0.71         8
#                       ghevar       0.88      0.97      0.93        38
#                  gulab_jamun       0.91      0.98      0.94        51
#                       imarti       0.75      0.38      0.50         8
#                       jalebi       0.94      0.99      0.97       203
#                      kachori       0.45      0.62      0.53         8
#                 kadai_paneer       0.74      0.91      0.82        70
#                 kadhi_pakoda       0.60      0.38      0.46         8
#                    kajjikaya       0.71      0.62      0.67         8
#               kakinada_khaja       0.80      1.00      0.89         8
#                     kalakand       0.89      1.00      0.94         8
#                karela_bharta       0.75      0.38      0.50         8
#                        kofta       0.92      0.96      0.94       108
#              kuzhi_paniyaram       0.56      0.62      0.59         8
#                        lassi       0.95      0.95      0.95        38
#                     ledikeni       0.50      0.12      0.20         8
#                 litti_chokha       0.40      0.50      0.44         8
#                     lyangcha       0.44      0.88      0.58         8
#                   maach_jhol       1.00      0.62      0.77         8
# makki_di_roti_sarson_da_saag       1.00      0.75      0.86         8
#                      malapua       0.57      0.50      0.53         8
#                    medu_vada       0.86      0.80      0.83        15
#                    misi_roti       0.71      0.62      0.67         8
#                    misti_doi       0.67      0.75      0.71         8
#                        modak       0.89      1.00      0.94        34
#                   mysore_pak       0.88      0.88      0.88         8
#                         naan       0.87      0.90      0.89        61
#              navrattan_korma       0.83      0.62      0.71         8
#                      noodles       0.91      0.91      0.91        11
#                 palak_paneer       0.91      0.99      0.94        68
#         paneer_butter_masala       0.67      0.25      0.36         8
#                    paniyaram       0.80      0.44      0.57         9
#                       phirni       0.75      0.38      0.50         8
#                        pithe       0.62      0.62      0.62         8
#                         poha       0.97      0.99      0.98        68
#                     poornalu       0.80      0.50      0.62         8
#                 pootharekulu       0.78      0.88      0.82         8
#                         puri       0.50      0.58      0.54        12
#             qubani_ka_meetha       0.43      0.38      0.40         8
#                        rabri       0.25      0.38      0.30         8
#                    ras_malai       0.83      0.89      0.86        38
#                     rasgulla       0.67      1.00      0.80         8
#                      sandesh       0.50      0.38      0.43         8
#                  shankarpali       1.00      0.88      0.93         8
#                  sheer_korma       0.54      0.88      0.67         8
#                       sheera       0.67      0.25      0.36         8
#                    shrikhand       0.75      0.38      0.50         8
#                  sohan_halwa       1.00      0.75      0.86         8
#                  sohan_papdi       1.00      0.62      0.77         8
#                   suji_halwa       0.50      0.45      0.48        11
#             tandoori_chicken       0.55      0.67      0.60         9
#                         upma       1.00      0.70      0.82        10
#                   ven_pongal       0.82      1.00      0.90         9
#
#                     accuracy                           0.82      1816
#                    macro avg       0.72      0.64      0.66      1816
#                 weighted avg       0.82      0.82      0.81      1816

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

cm = confusion_matrix(y_true, y_pred)

classes = test_dataset.classes

plt.figure(figsize=(10,10))
plt.imshow(cm)

plt.xticks(np.arange(len(classes)), classes, rotation=90)
plt.yticks(np.arange(len(classes)), classes)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")

plt.colorbar()
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.imshow(cm, cmap="Blues")

plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

for i in range(len(cm)):
    for j in range(len(cm)):
        plt.text(j, i, cm[i, j],
                 ha="center", va="center",
                 color="black")

plt.colorbar()
plt.show()

# %%
plt.figure()
plt.imshow(cm, cmap="Blues")   
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.colorbar()
plt.show()

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y_true, y_pred, average='weighted')
recall = recall_score(y_true, y_pred, average='weighted')
f1 = f1_score(y_true, y_pred, average='weighted')

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Precision: 0.8224901036600153
# Recall: 0.8237885462555066
# F1 Score: 0.8134835998268193

# %%
metrics = [precision, recall, f1]

plt.figure()
plt.bar(["Precision", "Recall", "F1"], metrics)
plt.title("Evaluation Metrics")
plt.show()

# %%
import numpy as np

classes = test_dataset.classes

confusions = []

for i in range(len(cm)):
    for j in range(len(cm)):
        if i != j and cm[i][j] > 0:
            confusions.append((classes[i], classes[j], cm[i][j]))


confusions_sorted = sorted(confusions, key=lambda x: x[2], reverse=True)

print("\nMost Confused Class Pairs:")
for i in range(10):
    print(confusions_sorted[i])
# Out:
# Most Confused Class Pairs:
# ('chapati', 'dum_aloo', np.int64(6))
# ('dal_tadka', 'dal_makhani', np.int64(6))
# ('chapati', 'naan', np.int64(5))
# ('paneer_butter_masala', 'kadai_paneer', np.int64(5))
# ('butter_chicken', 'chicken_tikka_masala', np.int64(4))
# ('imarti', 'jalebi', np.int64(4))
# ('naan', 'chapati', np.int64(4))
# ('paniyaram', 'kuzhi_paniyaram', np.int64(4))
# ('bhatura', 'puri', np.int64(3))
# ('chapati', 'dal_makhani', np.int64(3))

# %%
top_pairs = confusions_sorted[:10]

labels = [f"{a}->{b}" for a,b,_ in top_pairs]
values = [v for _,_,v in top_pairs]

import matplotlib.pyplot as plt

plt.figure()
plt.barh(labels, values)
plt.title("Top Confused Class Pairs")
plt.xlabel("Confusion Count")
plt.show()

# %%
from sklearn.metrics import classification_report

report = classification_report(
    y_true,
    y_pred,
    target_names=test_dataset.classes,
    output_dict=True
)

# %%
# store (class, f1-score)
f1_scores = []

for class_name in test_dataset.classes:
    f1 = report[class_name]["f1-score"]
    f1_scores.append((class_name, f1))

# sort
f1_scores_sorted = sorted(f1_scores, key=lambda x: x[1], reverse=True)

# top 10 best
top10 = f1_scores_sorted[:10]

# bottom 10 worst
bottom10 = f1_scores_sorted[-10:]

print("\nTop 10 Best Classes:")
for name, score in top10:
    print(name, "→", round(score, 3))

print("\nTop 10 Worst Classes:")
for name, score in bottom10:
    print(name, "→", round(score, 3))
# Out:
# Top 10 Best Classes:
# chikki → 1.0
# bhindi_masala → 0.978
# poha → 0.978
# biryani → 0.971
# jalebi → 0.966
# lassi → 0.947
# modak → 0.944
# palak_paneer → 0.944
# gulab_jamun → 0.943
# kalakand → 0.941
#
# Top 10 Worst Classes:
# paneer_butter_masala → 0.364
# sheera → 0.364
# dal_tadka → 0.333
# doodhpak → 0.333
# rabri → 0.3
# aloo_tikki → 0.267
# chicken_tikka_masala → 0.267
# ledikeni → 0.2
# chhena_kheeri → 0.143
# chicken_tikka → 0.0

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt
import numpy as np

num_classes = len(test_dataset.classes)

y_true = []
y_score = []

model.eval()
with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)

        outputs = model(images)
        probs = torch.softmax(outputs, dim=1)

        y_true.extend(labels.numpy())
        y_score.extend(probs.cpu().numpy())

y_true = np.array(y_true)
y_score = np.array(y_score)

# Binarize labels
y_true_bin = label_binarize(y_true, classes=list(range(num_classes)))

# Plot ROC
for i in range(num_classes):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_score[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"Class {i} (AUC = {roc_auc:.2f})")

plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
from sklearn.preprocessing import label_binarize

num_classes = y_score.shape[1]

y_true_bin = label_binarize(y_true, classes=list(range(num_classes)))
y_true_flat = y_true_bin.ravel()
y_score_flat = y_score.ravel()
from sklearn.metrics import precision_recall_curve

precision, recall, thresholds = precision_recall_curve(y_true_flat, y_score_flat)

# F1
f1_scores = 2 * (precision * recall) / (precision + recall + 1e-8)

# fix size mismatch
import numpy as np
thresholds = np.append(thresholds, 1.0)

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(thresholds, precision)
plt.xlabel("Threshold")
plt.ylabel("Precision")
plt.title("Precision vs Threshold(MobileNetV2)")
plt.show()

# %%
plt.figure()
plt.plot(thresholds, recall)
plt.xlabel("Threshold")
plt.ylabel("Recall")
plt.title("Recall vs Threshold (MobileNetV2)")
plt.show()

# %%
plt.figure()
plt.plot(thresholds, f1_scores)
plt.xlabel("Threshold")
plt.ylabel("F1 Score")
plt.title("F1 Score vs Threshold(MobileNetV2)")
plt.show()

# %%
import random
import matplotlib.pyplot as plt

classes = test_dataset.classes

def show_random_predictions(model, dataset, num_images=6):
    model.eval()

    indices = random.sample(range(len(dataset)), num_images)

    for idx in indices:
        image, label = dataset[idx]

        input_img = image.unsqueeze(0).to(device)

        with torch.no_grad():
            outputs = model(input_img)
            _, pred = torch.max(outputs, 1)

        img = image.permute(1, 2, 0).numpy()

        # Unnormalize
        img = img * [0.229, 0.224, 0.225] + [0.485, 0.456, 0.406]
        img = img.clip(0, 1)

        plt.imshow(img)
        plt.title(f"Pred: {classes[pred.item()]} | True: {classes[label]}")
        plt.axis('off')
        plt.show()

# %%
show_random_predictions(model, test_dataset, num_images=8)

# %%
torch.save(model.state_dict(), "/kaggle/working/mobilenet_food_89classes.pth")

# %%
torch.save(model.state_dict(), "/kaggle/working/best_model.pth")

# %%
import os
print(os.listdir("/kaggle/working"))
# Out:
# ['mobilenet_food_89classes.pth', '.virtual_documents', 'best_model.pth']
